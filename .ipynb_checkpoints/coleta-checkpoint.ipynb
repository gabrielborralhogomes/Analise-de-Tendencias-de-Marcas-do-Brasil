# %%
import os
import time
import pandas as pd
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options

servico = Service(ChromeDriverManager().install())

# Configuração do diretório de download
download_directory = os.path.join(os.getcwd(), "dados")
if not os.path.exists(download_directory):  # Cria a pasta se não existir
    os.makedirs(download_directory)

# Opções do Chrome
options = Options()
options.add_experimental_option("prefs", {
    "download.default_directory": download_directory,  # Define a pasta de download
    "download.prompt_for_download": False,  # Não solicita confirmação para downloads
    "directory_upgrade": True,
})

# Dicionário com as marcas e seus valores
dados = {
    "Marca": [
        "Itaú", "Banco do Brasil", "Bradesco", "Petrobras", "Vale"
    ],
    "Valor": [
        8330000000, 5450000000, 5010000000, 3400000000, 3000000000
    ]
}

# %%
# Inicia o driver do Chrome com as opções definidas
driver = webdriver.Chrome(options=options)

# Acessa o Google Trends
driver.get("https://trends.google.com/trends/explore?geo=BR&hl=pt-BR")

# Espera alguns segundos para garantir o carregamento da página
time.sleep(2)

# Recarrega a página
driver.refresh()

# Espera mais alguns segundos após a recarga
time.sleep(2)

# Inicializa ActionChains
actions = ActionChains(driver)

# Percorre cada marca no dicionário
for marca in dados["Marca"]:
    print(f"Pesquisando por: {marca}")

    # Pesquisa a marca
    search_box_xpath = '//*[@id="input-29"]'  # XPath da caixa de busca
    search_box = driver.find_element(By.XPATH, search_box_xpath)

    
    # Limpa a caixa de busca
    search_box.send_keys(Keys.BACKSPACE)  # Isso remove um caractere por vez
    for _ in range(len(search_box.get_attribute('value'))):  # Limpa todos os caracteres
        search_box.send_keys(Keys.BACKSPACE)
    
    # Digita a nova marca e submete a busca
    search_box.send_keys(marca)
    search_box.send_keys(Keys.RETURN)  # Submete a busca

    # Espera o carregamento dos dados e o botão de download
    time.sleep(5)

    # Clica no botão de download
    download_button_xpath = '/html/body/div[3]/div[2]/div/md-content/div/div/div[1]/trends-widget/ng-include/widget/div/div/div/widget-actions/div/button[1]/i'
    download_button = driver.find_element(By.XPATH, download_button_xpath)
    
    # Realiza o scroll até o botão e clica usando ActionChains
    actions.move_to_element(download_button).click().perform()

    # Aumenta o tempo de espera para o download completar
    time.sleep(10)  # Aumentando o tempo de espera

    # Verifica o último arquivo baixado na pasta de download
    file_list = os.listdir(download_directory)
    if file_list:  # Verifica se a lista não está vazia
        # Obtém o nome do arquivo mais recente
        file_name = file_list[-1]
        file_path = os.path.join(download_directory, file_name)

        # Renomeia o arquivo para o nome da marca
        new_file_path = os.path.join(download_directory, f"{marca}.csv")
        os.rename(file_path, new_file_path)  # Renomeia o arquivo

        # Lê o CSV renomeado
        df = pd.read_csv(new_file_path)

        print(f"Download e renomeação concluídos para: {marca}")
    else:
        print(f"Nenhum arquivo encontrado para a marca: {marca}")

    # Aguarda um pouco antes de começar a nova pesquisa
    time.sleep(2)  # Espera para garantir que o campo de pesquisa esteja limpo

# Fecha o navegador ao final
driver.quit()
# Out:
# Pesquisando por: Itaú
# Download e renomeação concluídos para: Itaú
# Pesquisando por: Banco do Brasil
# Download e renomeação concluídos para: Banco do Brasil
# Pesquisando por: Bradesco
# Download e renomeação concluídos para: Bradesco
# Pesquisando por: Petrobras
# Download e renomeação concluídos para: Petrobras
# Pesquisando por: Vale
# Download e renomeação concluídos para: Vale

# %%
marcas_valores = {
    "Marca": [
        "Itaú", "Banco do Brasil", "Bradesco", "Petrobras", "Vale", 
        "Caixa", "Localiza", "Brahma", "Natura", "Skol", 
        "Sadia", "Vivo", "Rede D’or São Luiz", "Nubank", "Marfrig", 
        "Latam Airlines", "Assai Atacadista", "Raízen", "Magazine Luiza", "Antarctica", 
        "Suzano", "Ipiranga", "Embraer", "Braskem", "Atacadão", 
        "Unidas", "Sabesp", "Klabin", "Movida", "PagSeguro Digital", 
        "Renner", "Camil", "Votorantim", "Globo", "Vibra", 
        "XP Inc.", "BNDES", "Gerdau", "Porto", "Itambé", 
        "SmartFit", "Minerva", "Stone", "Perdigão", "Neoenergia", 
        "Hapvida Participações e Investimentos", "B3", "Sul América", "Ypióca", "Banco Pan"
    ],
    "Valor": [
        8330000000, 5450000000, 5010000000, 3400000000, 3000000000, 
        2860000000, 2300000000, 1960000000, 1950000000, 1900000000, 
        1800000000, 1700000000, 1370000000, 1350000000, 1350000000, 
        1220000000, 1200000000, 1090000000, 994000000, 992000000, 
        920000000, 918000000, 864000000, 827000000, 820000000, 
        766000000, 751000000, 693000000, 682000000, 630000000, 
        615000000, 574000000, 569000000, 558000000, 553000000, 
        544000000, 543000000, 536000000, 500000000, 444000000, 
        432000000, 426000000, 416000000, 390000000, 388000000, 
        377000000, 358000000, 357000000, 354000000, 342000000
    ]
}
